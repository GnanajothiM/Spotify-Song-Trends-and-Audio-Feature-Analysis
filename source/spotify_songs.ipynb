# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df=pd.read_excel(r"C:\Users\Gnanajothi.M\OneDrive\Desktop\Spotify Song Trends and Audio Feature Analysis\dataset\spotify_songs.xlsx",header=None)

# %%
spotify=pd.read_excel(r"C:\Users\Gnanajothi.M\OneDrive\Desktop\Spotify Song Trends and Audio Feature Analysis\dataset\spotify_songs.xlsx")

# %%
spotify.head()
# Out:
#                  track_id                                         track_name  \
# 0  0017A6SJgTbfQVU2EtsPNo                                           Pangarap
# 1  004s3t0ONYlzxII9PLgU6z                                       I Feel Alive
# 2  00chLpzhgVjxs1zKC9UScL                                             Poison
# 3  00cqd6ZsSkLZqGMlQCR0Zo  Baby It's Cold Outside (feat. Christina Aguilera)
# 4  00emjlCv9azBN0fzuuyLqy                                         Dumb Litty
#
#       track_artist                                             lyrics  \
# 0  Barbie's Cradle  Minsan pa Nang ako'y napalingon Hindi ko alam ...
# 1    Steady Rollin  The trees, are singing in the wind The sky blu...
# 2   Bell Biv DeVoe  NA Yeah, Spyderman and Freeze in full effect U...
# 3      CeeLo Green  I really can't stay Baby it's cold outside I'v...
# 4             KARD  Get up out of my business You don't keep me fr...
#
#    track_popularity          track_album_id  \
# ...

# %%
spotify.tail()
# Out:
#                      track_id                              track_name  \
# 18449  7zXzWCVuz7whIuYZyEAlxt         Rising Like The Sun - Radio Mix
# 18450  7zycSpvjDcqh6YT1FEl2kY                                Anaconda
# 18451  7zye9v6B785eFWEFYs13C2                                   Bound
# 18452  7zyLObYw4QUKQDyZOb4J0Y  I'll Do 4 U (Re-Recorded / Remastered)
# 18453  7zzZmpw8L66ZPjH1M6qmOs                                Migraine
#
#                    track_artist  \
# 18449                   Qulinez
# 18450               Nicki Minaj
# 18451  Ponderosa Twins Plus One
# 18452                 Father MC
# 18453                Moonstar88
#
#                                                   lyrics  track_popularity  \
# 18449  Caught up in such a head rush, wide-eyed latel...                 0
# 18450  My anaconda don't, my anaconda don't My anacon...                49
# 18451  Bound, bound Bound, bound Bound to fall in lov...                40
# ...

# %%
spotify.sample(5)
# Out:
#                      track_id              track_name track_artist  \
# 7976   3gMJMSrU2QETbsILNuybIh     Make A Move - Pt. 2  EMMA WAHLIN
# 12360  5CE1jL4dkfZlX5CiHZh5ap      No Romeo No Juliet      50 Cent
# 1439   0nyrltZrQGAJMBZc1bYvuQ  Get Up Offa That Thing  James Brown
# 11504  4vSQiyuTOUHvKM043BGqa4           Eu Tenho Drip        Derek
# 5102   28WbijaWIjv7D6D4qVIcYQ                 Axolotl    The Veils
#
#                                                   lyrics  track_popularity  \
# 7976   Been feeling like I'm all alone Just wanna fin...                17
# 12360  Ayo, quit Captain Savin', serenadin' them hoes...                59
# 1439   Aaaaaaaaaaaaaaaaaaaw!!! Oh! Say it now!I'm bac...                53
# 11504  NA Hol up, hol up Hol up, hol up, hol up Hol u...                57
# 5102   I'm glowing bright, obsidian Axolotl amphibian...                33
#
#                track_album_id            track_album_name  \
# ...

# %%
type(spotify)
# Out:
# pandas.DataFrame

# %%
spotify.shape
# Out:
# (18454, 25)

# %%
spotify.columns
# Out:
# Index(['track_id', 'track_name', 'track_artist', 'lyrics', 'track_popularity',
#        'track_album_id', 'track_album_name', 'track_album_release_date',
#        'playlist_name', 'playlist_id', 'playlist_genre', 'playlist_subgenre',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'duration_ms', 'language'],
#       dtype='str')

# %%
spotify.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 18454 entries, 0 to 18453
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   track_id                  18454 non-null  str
#  1   track_name                18454 non-null  object
#  2   track_artist              18454 non-null  object
#  3   lyrics                    18194 non-null  str
#  4   track_popularity          18454 non-null  int64
#  5   track_album_id            18454 non-null  str
#  6   track_album_name          18454 non-null  object
#  7   track_album_release_date  18454 non-null  object
#  8   playlist_name             18454 non-null  str
#  9   playlist_id               18454 non-null  str
#  10  playlist_genre            18454 non-null  str
#  11  playlist_subgenre         18454 non-null  str
#  12  danceability              18454 non-null  float64
#  13  energy                    18454 non-null  float64
# ...

# %%
spotify.describe()
# Out:
#        track_popularity  danceability        energy           key  \
# count      18454.000000  18454.000000  18454.000000  18454.000000
# mean          42.438821      0.644066      0.692289      5.342094
# std           24.616740      0.150071      0.180635      3.613121
# min            0.000000      0.098500      0.016700      0.000000
# 25%           24.000000      0.546000      0.573000      2.000000
# 50%           48.000000      0.660000      0.715000      6.000000
# 75%           62.000000      0.755000      0.835000      9.000000
# max          100.000000      0.979000      1.000000     11.000000
#
#            loudness          mode   speechiness  acousticness  \
# count  18454.000000  18454.000000  18454.000000  18454.000000
# mean      -6.769159      0.580525      0.106192      0.175348
# std        2.920757      0.493487      0.102291      0.217795
# min      -34.283000      0.000000      0.022400      0.000001
# ...

# %%
spotify.isnull()
# Out:
#        track_id  track_name  track_artist  lyrics  track_popularity  \
# 0         False       False         False   False             False
# 1         False       False         False   False             False
# 2         False       False         False   False             False
# 3         False       False         False   False             False
# 4         False       False         False   False             False
# ...         ...         ...           ...     ...               ...
# 18449     False       False         False   False             False
# 18450     False       False         False   False             False
# 18451     False       False         False   False             False
# 18452     False       False         False   False             False
# 18453     False       False         False   False             False
#
#        track_album_id  track_album_name  track_album_release_date  \
# 0               False             False                     False
# ...

# %%
spotify.isnull().sum()
# Out:
# track_id                    0
# track_name                  0
# track_artist                0
# lyrics                      0
# track_popularity            0
# track_album_id              0
# track_album_name            0
# track_album_release_date    0
# playlist_name               0
# playlist_id                 0
# playlist_genre              0
# playlist_subgenre           0
# danceability                0
# energy                      0
# key                         0
# loudness                    0
# mode                        0
# speechiness                 0
# acousticness                0
# instrumentalness            0
# liveness                    0
# valence                     0
# tempo                       0
# duration_ms                 0
# language                    0
# dtype: int64

# %%
spotify.isnull().any(axis=1)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18449    False
# 18450    False
# 18451    False
# 18452    False
# 18453    False
# Length: 18454, dtype: bool

# %%
spotify.isnull().all()
# Out:
# track_id                    False
# track_name                  False
# track_artist                False
# lyrics                      False
# track_popularity            False
# track_album_id              False
# track_album_name            False
# track_album_release_date    False
# playlist_name               False
# playlist_id                 False
# playlist_genre              False
# playlist_subgenre           False
# danceability                False
# energy                      False
# key                         False
# loudness                    False
# mode                        False
# speechiness                 False
# acousticness                False
# instrumentalness            False
# liveness                    False
# valence                     False
# tempo                       False
# duration_ms                 False
# language                    False
# dtype: bool

# %%
spotify[spotify.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [track_id, track_name, track_artist, lyrics, track_popularity, track_album_id, track_album_name, track_album_release_date, playlist_name, playlist_id, playlist_genre, playlist_subgenre, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, duration_ms, language]
# Index: []
#
# [0 rows x 25 columns]

# %%
spotify["lyrics"] = spotify["lyrics"].fillna("Unknown")

# %%
spotify["language"] = spotify["language"].fillna("Unknown")

# %%
spotify.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 18454 entries, 0 to 18453
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   track_id                  18454 non-null  str
#  1   track_name                18454 non-null  object
#  2   track_artist              18454 non-null  object
#  3   lyrics                    18454 non-null  str
#  4   track_popularity          18454 non-null  int64
#  5   track_album_id            18454 non-null  str
#  6   track_album_name          18454 non-null  object
#  7   track_album_release_date  18454 non-null  object
#  8   playlist_name             18454 non-null  str
#  9   playlist_id               18454 non-null  str
#  10  playlist_genre            18454 non-null  str
#  11  playlist_subgenre         18454 non-null  str
#  12  danceability              18454 non-null  float64
#  13  energy                    18454 non-null  float64
# ...

# %%
spotify.shape
# Out:
# (18454, 25)

# %%
spotify.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18449    False
# 18450    False
# 18451    False
# 18452    False
# 18453    False
# Length: 18454, dtype: bool

# %%
spotify.duplicated().sum()
# Out:
# np.int64(0)
